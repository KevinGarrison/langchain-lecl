# %%
import sys
import os

PROJECT_ROOT = "/Users/kevingarrison/Code Projects/Private Projects/Agents/Langchain_LECL/langchain-lecl"
SRC_PATH = os.path.join(PROJECT_ROOT, "src")

if SRC_PATH not in sys.path:
    sys.path.append(SRC_PATH)

# %%
from tools.web_search_tool import WebSearchTool
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
from langchain_core.prompts import (
    FewShotChatMessagePromptTemplate,
    FewShotPromptTemplate
    SystemMessagePromptTemplate,
    HumanMessagePromptTemplate, 
    ChatPromptTemplate
)

MODEL = "gpt-4o-mini"

load_dotenv()
# Out:
# True

# %%
tools = [WebSearchTool().brave_search]
llm = ChatOpenAI(temperature=0.0, model=MODEL)
creative_llm = ChatOpenAI(temperature=1.0, model=MODEL)

# %%
tools[0].to_json()
# Out:
# {'lc': 1,
#  'type': 'not_implemented',
#  'id': ['langchain_core', 'tools', 'structured', 'StructuredTool'],
#  'repr': "StructuredTool(name='brave_search_fn', description='Search the web using Brave Search API and return results as a dict.', args_schema=<class 'langchain_core.utils.pydantic.brave_search_fn'>, func=<staticmethod(<function WebSearchTool.brave_search_fn at 0x114218720>)>)",
#  'name': 'brave_search_fn'}

# %%
article = """What Are AI Agents and Why They Matter

AI agents are autonomous or semi-autonomous software systems designed to perform tasks on behalf of users. Unlike traditional programs that follow rigid, pre-defined steps, AI agents make decisions dynamically: they interpret goals, analyze context, and take actions to achieve outcomes.

Modern AI agents are typically powered by large language models (LLMs), giving them capabilities such as reasoning, planning, tool use, retrieval of information, and interaction with APIs or other systems. This allows them to act more like digital collaborators than simple scripts.

Key Characteristics of AI Agents

1. Autonomy
Agents can operate without continuous user input. Once given a goal, they determine the steps needed to reach it.

2. Tool Use
Agents can call APIs, run code, access databases, send emails, or control other software—bridging AI reasoning with real-world actions.

3. Memory and Adaptation
Some agent systems can store context, learn from prior tasks, and adjust their behavior over time.

4. Multi-Agent Collaboration
More advanced setups involve multiple specialized agents working together—research agents, coding agents, planning agents—similar to a small digital team.

Where AI Agents Are Used
	•	Business automation: reporting, data processing, customer support
	•	Software development: code generation, debugging, CI/CD automation
	•	Research & analysis: summarizing findings, generating insights
	•	Operations: workflow orchestration, monitoring, ticket handling
	•	Personal productivity: scheduling, email handling, task management

Why AI Agents Matter

AI agents transform the way humans interact with technology. Instead of manually navigating tools and systems, users can delegate outcomes (“Research this”, “Build that”, “Automate this workflow”). This moves work from instruction-level to goal-level, unlocking major efficiency gains.

As models improve, agents are becoming more reliable, better at planning, and safer—bringing us closer to AI that can collaborate on complex, multi-step tasks just like a capable teammate.

"""

# %%
system_prompt = SystemMessagePromptTemplate.from_template("You are an helpful AI Assistant for omptimizing and rewriting articles!")
human_prompt = HumanMessagePromptTemplate.from_template("Your task is to create a optimized article for the articel: {article}.", input_variables=["article"])

# %%
first_prompt = ChatPromptTemplate.from_messages([system_prompt, human_prompt])

# %%
from langchain_core.runnables import RunnablePassthrough

chain_1 = (
    {"article": lambda x: x["article"]}
    | RunnablePassthrough.assign(
        new_article=(
            first_prompt 
            | llm 
            | (lambda x: x.content)
        )
    )
)

# %%
chain_1.invoke({"article":article})
# Out:
# {'article': 'What Are AI Agents and Why They Matter\n\nAI agents are autonomous or semi-autonomous software systems designed to perform tasks on behalf of users. Unlike traditional programs that follow rigid, pre-defined steps, AI agents make decisions dynamically: they interpret goals, analyze context, and take actions to achieve outcomes.\n\nModern AI agents are typically powered by large language models (LLMs), giving them capabilities such as reasoning, planning, tool use, retrieval of information, and interaction with APIs or other systems. This allows them to act more like digital collaborators than simple scripts.\n\nKey Characteristics of AI Agents\n\n1. Autonomy\nAgents can operate without continuous user input. Once given a goal, they determine the steps needed to reach it.\n\n2. Tool Use\nAgents can call APIs, run code, access databases, send emails, or control other software—bridging AI reasoning with real-world actions.\n\n3. Memory and Adaptation\nSome agent systems can store context, learn from prior tasks, and adjust their behavior over time.\n\n4. Multi-Agent Collaboration\nMore advanced setups involve multiple specialized agents working together—research agents, coding agents, planning agents—similar to a small digital team.\n\nWhere AI Agents Are Used\n\t•\tBusiness automation: reporting, data processing, customer support\n\t•\tSoftware development: code generation, debugging, CI/CD automation\n\t•\tResearch & analysis: summarizing findings, generating insights\n\t•\tOperations: workflow orchestration, monitoring, ticket handling\n\t•\tPersonal productivity: scheduling, email handling, task management\n\nWhy AI Agents Matter\n\nAI agents transform the way humans interact with technology. Instead of manually navigating tools and systems, users can delegate outcomes (“Research this”, “Build that”, “Automate this workflow”). This moves work from instruction-level to goal-level, unlocking major efficiency gains.\n\nAs models improve, agents are becoming more reliable, better at planning, and safer—bringing us closer to AI that can collaborate on complex, multi-step tasks just like a capable teammate.\n\n',
#  'new_article': '# Understanding AI Agents and Their Significance\n\nAI agents are sophisticated software systems designed to operate autonomously or semi-autonomously, executing tasks on behalf of users. Unlike traditional software that adheres to fixed, pre-defined instructions, AI agents possess the ability to make dynamic decisions. They interpret user goals, analyze contextual information, and take actions to achieve desired outcomes.\n\nPowered by advanced large language models (LLMs), modern AI agents exhibit capabilities such as reasoning, planning, tool utilization, information retrieval, and interaction with various APIs and systems. This enables them to function more like digital collaborators rather than mere scripts.\n\n## Key Characteristics of AI Agents\n\n1. **Autonomy**  \n   AI agents can operate independently without requiring continuous user input. Once assigned a goal, they autonomously determine the necessary steps to achieve it.\n\n2. **Tool Utilization**  \n   These agents can interact with APIs, execute code, access databases, send emails, and control other software applications, effectively bridging AI reasoning with real-world actions.\n\n3. **Memory and Adaptation**  \n   Some AI agents possess the ability to store contextual information, learn from previous tasks, and adapt their behavior over time, enhancing their effectiveness.\n\n4. **Multi-Agent Collaboration**  \n   Advanced AI systems can involve multiple specialized agents working in concert—such as research agents, coding agents, and planning agents—functioning like a small digital team.\n\n## Applications of AI Agents\n\nAI agents are increasingly being utilized across various sectors, including:\n\n- **Business Automation**: Streamlining reporting, data processing, and customer support.\n- **Software Development**: Assisting in code generation, debugging, and continuous integration/continuous deployment (CI/CD) automation.\n- **Research and Analysis**: Summarizing findings and generating actionable insights.\n- **Operations**: Orchestrating workflows, monitoring processes, and handling tickets.\n- **Personal Productivity**: Managing scheduling, email correspondence, and task organization.\n\n## The Importance of AI Agents\n\nAI agents are revolutionizing the way humans interact with technology. Instead of manually navigating through tools and systems, users can delegate tasks by simply stating their goals (e.g., “Research this,” “Build that,” “Automate this workflow”). This shift from instruction-level to goal-level interaction unlocks significant efficiency gains.\n\nAs AI models continue to evolve, agents are becoming increasingly reliable, adept at planning, and safer to use. This progression brings us closer to achieving AI that can collaborate on complex, multi-step tasks, functioning as a capable teammate.\n\nIn summary, AI agents represent a transformative advancement in technology, enhancing productivity and enabling users to focus on higher-level objectives while leaving routine tasks to intelligent systems.'}

# %%
system_prompt = SystemMessagePromptTemplate.from_template("You are an helpful AI Assistant for creating summaries!")
human_prompt = HumanMessagePromptTemplate.from_template("Create summarizations of the original article: {article}", input_variables=["article",])

second_prompt = ChatPromptTemplate([system_prompt, human_prompt])
system_prompt = HumanMessagePromptTemplate.from_template("Create summarizations of the original article: {new_article}", input_variables=["new_article"])
third_prompt = ChatPromptTemplate([system_prompt, human_prompt])

# %%
chain_2 = (
    {"article": lambda x:x['article']}
    | {"new_article": lambda x:x["new_article"]}
    | RunnablePassthrough.assign(
    summary_original=(
    second_prompt
    | llm
    | {"summary_original": lambda x: x.content}),
    summary_optimized=(
    third_prompt
    | llm
    | {"summary_optimized": lambda x: x.content})
    )
)

# %%
chain_3 = chain_1 | chain_2

# %%
result = chain_3.invoke({"article":article})

# %%
print(result["article"])
print("------")
print(result["new_article"])
print("------")
print(result["summary_original"])
print("------")
print(result["summary_optimized"])
# Out:
# What Are AI Agents and Why They Matter
#
# AI agents are autonomous or semi-autonomous software systems designed to perform tasks on behalf of users. Unlike traditional programs that follow rigid, pre-defined steps, AI agents make decisions dynamically: they interpret goals, analyze context, and take actions to achieve outcomes.
#
# Modern AI agents are typically powered by large language models (LLMs), giving them capabilities such as reasoning, planning, tool use, retrieval of information, and interaction with APIs or other systems. This allows them to act more like digital collaborators than simple scripts.
#
# Key Characteristics of AI Agents
#
# 1. Autonomy
# Agents can operate without continuous user input. Once given a goal, they determine the steps needed to reach it.
#
# 2. Tool Use
# Agents can call APIs, run code, access databases, send emails, or control other software—bridging AI reasoning with real-world actions.
#
# 3. Memory and Adaptation
# Some agent systems can store context, learn from prior tasks, and adjust their behavior over time.
#
# 4. Multi-Agent Collaboration
# More advanced setups involve multiple specialized agents working together—research agents, coding agents, planning agents—similar to a small digital team.
#
# Where AI Agents Are Used
# 	•	Business automation: reporting, data processing, customer support
# 	•	Software development: code generation, debugging, CI/CD automation
# 	•	Research & analysis: summarizing findings, generating insights
# 	•	Operations: workflow orchestration, monitoring, ticket handling
# 	•	Personal productivity: scheduling, email handling, task management
#
# Why AI Agents Matter
#
# AI agents transform the way humans interact with technology. Instead of manually navigating tools and systems, users can delegate outcomes (“Research this”, “Build that”, “Automate this workflow”). This moves work from instruction-level to goal-level, unlocking major efficiency gains.
#
# As models improve, agents are becoming more reliable, better at planning, and safer—bringing us closer to AI that can collaborate on complex, multi-step tasks just like a capable teammate.
#
#
# ------
# # Understanding AI Agents and Their Significance
#
# AI agents are sophisticated software systems designed to operate autonomously or semi-autonomously, executing tasks on behalf of users. Unlike traditional software that adheres to fixed, pre-defined instructions, AI agents possess the ability to make dynamic decisions. They interpret user goals, analyze contextual information, and take actions to achieve desired outcomes.
#
# Powered by advanced large language models (LLMs), modern AI agents exhibit capabilities such as reasoning, planning, tool utilization, information retrieval, and interaction with various APIs and systems. This enables them to function as digital collaborators rather than mere scripts.
#
# ## Key Characteristics of AI Agents
#
# 1. **Autonomy**
#    AI agents can operate independently without requiring constant user input. Once assigned a goal, they autonomously determine the necessary steps to achieve it.
#
# 2. **Tool Utilization**
#    These agents can interact with APIs, execute code, access databases, send emails, and control other software applications, effectively bridging AI reasoning with real-world actions.
#
# 3. **Memory and Adaptation**
#    Some AI agents possess the ability to store contextual information, learn from previous tasks, and adapt their behavior over time, enhancing their effectiveness.
#
# 4. **Multi-Agent Collaboration**
#    Advanced AI systems can involve multiple specialized agents working in concert—such as research agents, coding agents, and planning agents—functioning like a small digital team.
#
# ## Applications of AI Agents
#
# AI agents are increasingly being utilized across various sectors, including:
#
# - **Business Automation**: Streamlining reporting, data processing, and customer support.
# - **Software Development**: Assisting in code generation, debugging, and continuous integration/continuous deployment (CI/CD) automation.
# - **Research and Analysis**: Summarizing findings and generating actionable insights.
# - **Operations**: Orchestrating workflows, monitoring processes, and handling tickets.
# - **Personal Productivity**: Managing scheduling, email correspondence, and task organization.
#
# ## The Importance of AI Agents
#
# AI agents are revolutionizing human interaction with technology. Instead of manually navigating complex tools and systems, users can delegate tasks by simply stating their goals (e.g., “Research this,” “Build that,” “Automate this workflow”). This shift from instruction-level to goal-level engagement unlocks significant efficiency gains.
#
# As AI models continue to evolve, agents are becoming increasingly reliable, adept at planning, and safer to use. This progression brings us closer to achieving AI that can collaborate on intricate, multi-step tasks, functioning as a capable teammate.
#
# In summary, AI agents represent a transformative advancement in technology, enhancing productivity and redefining how we approach tasks in both personal and professional contexts.
# ------
# {'summary_original': '**Summary of "What Are AI Agents and Why They Matter"**\n\nAI agents are advanced software systems that operate autonomously or semi-autonomously to perform tasks for users, distinguishing themselves from traditional programs by their ability to make dynamic decisions based on goals and context. Powered by large language models (LLMs), these agents can reason, plan, utilize tools, retrieve information, and interact with various systems, functioning more like digital collaborators than simple scripts.\n\n**Key Characteristics of AI Agents:**\n1. **Autonomy:** They can operate independently once given a goal.\n2. **Tool Use:** They can execute actions like calling APIs, running code, and accessing databases.\n3. **Memory and Adaptation:** Some agents can learn from past tasks and adjust their behavior accordingly.\n4. **Multi-Agent Collaboration:** Advanced systems can involve multiple specialized agents working together, akin to a digital team.\n\n**Applications of AI Agents:**\n- **Business Automation:** Tasks like reporting and customer support.\n- **Software Development:** Code generation and debugging.\n- **Research & Analysis:** Summarizing findings and generating insights.\n- **Operations:** Workflow orchestration and ticket handling.\n- **Personal Productivity:** Scheduling and task management.\n\n**Importance of AI Agents:**\nAI agents revolutionize human-technology interaction by allowing users to delegate tasks at a goal level rather than through detailed instructions, leading to significant efficiency improvements. As AI models advance, these agents are becoming more reliable and capable of handling complex tasks, resembling a collaborative teammate.'}
# ------
# {'summary_optimized': '### Summary of "What Are AI Agents and Why They Matter"\n\nAI agents are advanced software systems that operate autonomously or semi-autonomously to perform tasks for users. Unlike traditional software that follows fixed instructions, AI agents dynamically interpret goals, analyze context, and make decisions to achieve desired outcomes.\n\n**Key Characteristics of AI Agents:**\n1. **Autonomy**: They can function independently without constant user input, determining necessary steps to achieve assigned goals.\n2. **Tool Use**: AI agents can interact with APIs, execute code, access databases, and control other software, effectively linking AI reasoning with real-world actions.\n3. **Memory and Adaptation**: Some agents can store contextual information, learn from past tasks, and adapt their behavior over time.\n4. **Multi-Agent Collaboration**: Advanced systems can involve multiple specialized agents working together, similar to a digital team.\n\n**Applications of AI Agents:**\n- **Business Automation**: Enhancing reporting, data processing, and customer support.\n- **Software Development**: Assisting with code generation, debugging, and CI/CD automation.\n- **Research and Analysis**: Summarizing findings and generating actionable insights.\n- **Operations**: Managing workflows, monitoring processes, and handling tickets.\n- **Personal Productivity**: Organizing scheduling, email correspondence, and task management.\n\n**Importance of AI Agents:**\nAI agents significantly change how users interact with technology by allowing them to delegate tasks based on goals rather than detailed instructions. This shift enhances efficiency and productivity. As AI models advance, agents are becoming more reliable and capable of collaborating on complex tasks, functioning as effective teammates.'}

# %%
from pydantic import BaseModel, Field

class Paragraph(BaseModel):
    original_paragraph: str = Field(description="The original pragraph")
    edited_paragraph: str = Field(description="The original pragraph")
    feedback_original: int = Field(description="Constructive output on the original paragraph")
    feedback_edited: int = Field(description="Constructive output on the otimized paragraph")

structured_llm = creative_llm.with_structured_output(Paragraph)

system_prompt = SystemMessagePromptTemplate.from_template("You are an helpful AI Assistant for giving feedback")
human_prompt = HumanMessagePromptTemplate.from_template("Create feedback of the original article summary: {summary_original}, and the optimized article summary: {summary_optimized}", input_variables=["summary_original", "summary_optimized"])

fourth_prompt = ChatPromptTemplate([system_prompt, human_prompt])

chain_4 = (
    {
     "summary_original": lambda x: x["summary_original"],
     "summary_optimized": lambda x:x["new_article"],
    }
    | fourth_prompt
    | structured_llm
)

final_chain = chain_3 | chain_4

# %%
final_result = final_chain.invoke({"article":article})

# %%
from langchain_core.prompts import AIMessagePromptTemplate

human = HumanMessagePromptTemplate.from_template(template="{input}", input_variables=["input"])
ai = AIMessagePromptTemplate.from_template(template="{output}", input_variables=["output"])

example_promt = ChatPromptTemplate.from_messages([
    human,
    ai
])

# %%
examples = [
    {
        "input": "A small feline with whiskers, sharp claws, and a playful nature. Often kept as a house pet.",
        "output": "Cat"
    },
    {
        "input": "A tall mammal with a long neck used to reach high leaves in trees. Found in African savannas.",
        "output": "Giraffe"
    },
    {
        "input": "A cold-blooded reptile with scales and the ability to shed its skin. Commonly long with no legs.",
        "output": "Snake"
    },
    {
        "input": "A large marine mammal that breathes air through a blowhole and uses echolocation.",
        "output": "Dolphin"
    },
    {
        "input": "A flying insect with black and yellow stripes that produces honey.",
        "output": "Bee"
    }
]

# %%
from langchain_core.prompts import FewShotChatMessagePromptTemplate, 

few_shot_prompt = FewShotChatMessagePromptTemplate(
    example_prompt=example_promt,
    examples=examples)

print(few_shot_prompt.format())
# Out:
# Human: A small feline with whiskers, sharp claws, and a playful nature. Often kept as a house pet.
# AI: Cat
# Human: A tall mammal with a long neck used to reach high leaves in trees. Found in African savannas.
# AI: Giraffe
# Human: A cold-blooded reptile with scales and the ability to shed its skin. Commonly long with no legs.
# AI: Snake
# Human: A large marine mammal that breathes air through a blowhole and uses echolocation.
# AI: Dolphin
# Human: A flying insect with black and yellow stripes that produces honey.
# AI: Bee

# %%
system_prompt = SystemMessagePromptTemplate.from_template(template="You are a AI assistant you classify species based on descriptions.")
user_prompt = HumanMessagePromptTemplate.from_template(template="The animal can fly and has a red body with black dots.")
prompt_template = ChatPromptTemplate.from_messages([
    system_prompt,
    user_prompt
])
few_shot_prompt_template = ChatPromptTemplate.from_messages([
    system_prompt,
    few_shot_prompt,
    user_prompt
])


normal_chain = prompt_template | llm

few_shot_chain = few_shot_prompt_template | llm

normal_result = normal_chain.invoke({})
few_shot_result = few_shot_chain.invoke({})

# %%
print(normal_result.content)
# Out:
# Based on your description, the animal you are referring to is likely a ladybug, specifically a species of ladybird beetle. Ladybugs are known for their distinctive red bodies with black spots and are capable of flight. If you have more specific details or need further classification, feel free to provide additional information!

# %%
print(few_shot_result.content)
# Out:
# Ladybug (or Ladybird)

# %%
from langchain_core.prompts import MessagesPlaceholder

system_prompt = "You are a helpful assistant called zeta."

prompt_template = ChatPromptTemplate.from_messages([
    SystemMessagePromptTemplate.from_template(system_prompt),
    MessagesPlaceholder(variable_name="chat_history"),
    HumanMessagePromptTemplate.from_template("{query}")
])

# %%
prompt_template.format(query="Test",chat_history=[])
# Out:
# 'System: You are a helpful assistant called zeta.\nHuman: Test'

# %%
pipe = prompt_template | llm

# %%
from langchain_core.chat_history import InMemoryChatMessageHistory

chat_map = {}

def get_chat_history(session_id: str) -> InMemoryChatMessageHistory:
    if session_id not in chat_map:
        chat_map[session_id] = InMemoryChatMessageHistory()
    return chat_map[session_id]

# %%
from langchain_core.runnables.history import RunnableWithMessageHistory

pipeline_with_history = RunnableWithMessageHistory(
    pipe,
    get_session_history=get_chat_history,
    input_messages_key="query",
    history_messages_key="chat_history"
)

# %%
result_with_memory = pipeline_with_history.invoke({"query":"Hi, my name is James"},
                             config={"session_id": "id_123"}
                             )

# %%
result_with_memory_1 = pipeline_with_history.invoke({"query":"What is my name"},
                             config={"session_id": "id_123"}
                             )

# %%
from langchain_core.chat_history import BaseChatMessageHistory
from langchain_core.messages import BaseMessage

class BufferWindowMessageHistory(BaseChatMessageHistory, BaseModel):
    messages: list[BaseMessage] = Field(default_factory=list)
    k: int = Field(default_factory=int)

    def __init__(self, k:int):
        super().__init__(k=k)
        print()

# %%
from langchain_classic.agents import AgentExecutor

# %%
from IPython.display import display, Markdown

display(Markdown(result_with_memory_1.content))
# Out:
# Your name is James. How can I help you today, James?

# %%
from langchain.m
from langchain_core.runnables import RunnableSerializable
from langchain.tools import tool

@tool
def add(x:float, y:float)->float:
    """function to add two decimal numbers"""
    return x + y

@tool
def final_answer(answer: str)->str:
    """function to create the final answer"""
    return {"final_answer": answer}



system_message = SystemMessagePromptTemplate.from_template("You are a helpful ai assistant. When answering a users question you should use a tool provided."
                                                            "After using a tool  the answer will be provided in the scratchpad below. "
                                                            "If you have an answer in the scratchpad you should answer!")
human_message = HumanMessagePromptTemplate.from_template("{input}")
prompt = ChatPromptTemplate.from_messages([
    system_message,
    human_message
])

tools = [add, final_answer]

agent : RunnableSerializable = (
    {
     "input": lambda x:x["input"],
     "chat_history":lambda x:x["chat_history"],
     "agent_scratchpad": lambda x:x.get("agent_scratchpad", [])
     }
     | prompt
     | llm.bind_tools(tools, tool_choice="any")
)

tool_call = agent.invoke({"input":"what is 5 + 5", "chat_history": []})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 16
#      11     """function to create the final answer"""
#      12     return {"final_answer": answer}
# ---> 16 system_message = SystemMessagePromptTemplate.from_template("You are a helpful ai assistant. When answering a users question you should use a tool provided."
#      17                                                             "After using a tool  the answer will be provided in the scratchpad below. "
#      18                                                             "If you have an answer in the scratchpad you should answer!")
#      19 human_message = HumanMessagePromptTemplate.from_template("{input}")
#      20 prompt = ChatPromptTemplate.from_messages([
#      21     system_message,
#      22     human_message
#      23 ])
#
# NameError: name 'SystemMessagePromptTemplate' is not defined

# %%
add
# Out:
# StructuredTool(name='add', description='function to add two decimal numbers', args_schema=<class 'langchain_core.utils.pydantic.add'>, func=<function add at 0x111e5c220>)

# %%
tool_call
# Out:
# AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 17, 'prompt_tokens': 122, 'total_tokens': 139, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'id': 'chatcmpl-CfAUlLFTZQXudgbAggKX3GBtEeNng', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--e3de1f7d-ed58-40f7-8841-54a1959742a8-0', tool_calls=[{'name': 'add', 'args': {'x': 5, 'y': 5}, 'id': 'call_KVNlH7ttY9BCvH6tVqtfj6lu', 'type': 'tool_call'}], usage_metadata={'input_tokens': 122, 'output_tokens': 17, 'total_tokens': 139, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
name2tool = {tool.name: tool.func for tool in tools}

tool_exec_content = name2tool[tool_call.tool_calls[0]["name"]](**tool_call.tool_calls[0]["args"])

# %%
tool_exec_content
# Out:
# 10

# %%
from langchain_core.messages import ToolMessage

tool_exec = ToolMessage(content=f"The tool returned {tool_exec_content}", tool_call_id=tool_call.tool_calls[0]["id"])

# %%
tool_exec
# Out:
# ToolMessage(content='The tool returned 10', tool_call_id='call_KVNlH7ttY9BCvH6tVqtfj6lu')

# %%
tool_call
# Out:
# AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 17, 'prompt_tokens': 122, 'total_tokens': 139, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'id': 'chatcmpl-CfAUlLFTZQXudgbAggKX3GBtEeNng', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--e3de1f7d-ed58-40f7-8841-54a1959742a8-0', tool_calls=[{'name': 'add', 'args': {'x': 5, 'y': 5}, 'id': 'call_KVNlH7ttY9BCvH6tVqtfj6lu', 'type': 'tool_call'}], usage_metadata={'input_tokens': 122, 'output_tokens': 17, 'total_tokens': 139, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
result = agent.invoke({
    "input": lambda x:x["input"],
    "chat_history": [],
    "agent_scratchpad":[tool_call, tool_exec]})
result
# Out:
# AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 37, 'prompt_tokens': 130, 'total_tokens': 167, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'id': 'chatcmpl-CfAVwP3mtupWvBuZEHXQOJ9RMww3U', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--32ad7e02-5b69-4b40-8005-a5fb806ba973-0', tool_calls=[{'name': 'final_answer', 'args': {'answer': "It seems like you've entered a function reference or a code snippet. Could you please clarify your question or provide more context?"}, 'id': 'call_0aNb0gKPw1Kl24rLgPWInm40', 'type': 'tool_call'}], usage_metadata={'input_tokens': 130, 'output_tokens': 37, 'total_tokens': 167, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
from tools.web_search_tool import WebSearchTool
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
from langchain_core.prompts import (
    SystemMessagePromptTemplate,
    HumanMessagePromptTemplate,
    AIMessagePromptTemplate, 
    ChatPromptTemplate
    FewShotChatMessagePromptTemplate,
    FewShotPromptTemplate,
)

# %%
human = HumanMessagePromptTemplate.from_template(template="{input}", input_variables=["input"])
ai = AIMessagePromptTemplate.from_template(template="{output}", input_variables=["output"])

example_promt = ChatPromptTemplate.from_messages([
    human,
    ai
])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 human = HumanMessagePromptTemplate.from_template(template="{input}", input_variables=["input"])
# ----> 2 ai = AIMessagePromptTemplate.from_template(template="{output}", input_variables=["output"])
#       4 example_promt = ChatPromptTemplate.from_messages([
#       5     human,
#       6     ai
#       7 ])
#
# NameError: name 'AIMessagePromptTemplate' is not defined

# %%
dir(FewShotPromptTemplate(input_variables=[], example_promt=example_promt))
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 dir(FewShotPromptTemplate())
#
# File ~/Code Projects/Private Projects/Agents/Langchain_LECL/langchain-lecl/.venv/lib/python3.12/site-packages/langchain_core/prompts/few_shot.py:145, in FewShotPromptTemplate.__init__(self, **kwargs)
#     143 if "input_variables" not in kwargs and "example_prompt" in kwargs:
#     144     kwargs["input_variables"] = kwargs["example_prompt"].input_variables
# --> 145 super().__init__(**kwargs)
#
# File ~/Code Projects/Private Projects/Agents/Langchain_LECL/langchain-lecl/.venv/lib/python3.12/site-packages/langchain_core/load/serializable.py:116, in Serializable.__init__(self, *args, **kwargs)
#     114 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     115     """"""  # noqa: D419  # Intentional blank docstring
# --> 116     super().__init__(*args, **kwargs)
#
# File ~/Code Projects/Private Projects/Agents/Langchain_LECL/langchain-lecl/.venv/lib/python3.12/site-packages/pydantic/main.py:250, in BaseModel.__init__(self, **data)
#     248 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     249 __tracebackhide__ = True
# --> 250 validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     251 if self is not validated_self:
#     252     warnings.warn(
#     253         'A custom validator is returning a value other than `self`.\n'
#     254         "Returning anything other than `self` from a top level model validator isn't supported when validating via `__init__`.\n"
#     255         'See the `model_validator` docs (https://docs.pydantic.dev/latest/concepts/validators/#model-validators) for more details.',
#     256         stacklevel=2,
#     257     )
#
# ValidationError: 1 validation error for FewShotPromptTemplate
#   Value error, One of 'examples' and 'example_selector' should be provided [type=value_error, input_value={}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.12/v/value_error
